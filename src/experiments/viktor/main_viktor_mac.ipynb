# %% [markdown]
# # ABS Project Viktor Notebook

# %%
# !git clone https://github.com/Itonkdong/abs-project.git
# Out:
# Cloning into 'abs-project'...
# remote: Enumerating objects: 338, done.
# remote: Counting objects: 100% (338/338), done.
# remote: Compressing objects: 100% (232/232), done.
# remote: Total 338 (delta 94), reused 323 (delta 85), pack-reused 0 (from 0)
# Receiving objects: 100% (338/338), 183.91 KiB | 5.57 MiB/s, done.
# Resolving deltas: 100% (94/94), done.

# %%
# %cd abs-project/
# Out:
# /content/abs-project

# %%
# !pip install -U torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 138.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 71.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 9.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -r docs/requirements.txt
# Out:
# ...
#   Cloning https://github.com/matteobettini/benchmarl_sphinx_theme.git to /tmp/pip-req-build-184cl57a
#   Running command git clone --filter=blob:none --quiet https://github.com/matteobettini/benchmarl_sphinx_theme.git /tmp/pip-req-build-184cl57a
#   Resolved https://github.com/matteobettini/benchmarl_sphinx_theme.git to commit 28949dd4821445c7190b2f7e6645a3c6827dc321
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 56.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 95.7 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# benchmarl  examples    notebooks       README.md  setup.py
# docs	   fine_tuned  pyproject.toml  setup.cfg  test

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/abs-project
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 60.1 MB/s eta 0:00:00
# ...
#   Building editable for benchmarl (pyproject.toml) ... done
#   Created wheel for benchmarl: filename=benchmarl-1.5.1-0.editable-py3-none-any.whl size=2952 sha256=ad51a33eee1c7d0fe7a287f1c0a33c8729b7c0dbaaa2cc91d0434df372bf701f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5wt1susd/wheels/17/bb/73/095a7528c44a684f321949014f91c338b77d999ab142e56c3d
# Successfully built benchmarl
# ...

# %%
# !apt-get update
# !apt-get install -y x11-utils python3-opengl xvfb
# !pip install pyvirtualdisplay
import pyvirtualdisplay
display = pyvirtualdisplay.Display(visible=False, size=(1400, 900))
display.start()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,233 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,593 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,637 kB]
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
import torch
from benchmarl.algorithms import MappoConfig, QmixConfig, MasacConfig, MaddpgConfig
from benchmarl.benchmark import Benchmark
from benchmarl.environments import VmasTask
from benchmarl.experiment import Experiment, ExperimentConfig
from benchmarl.models import MlpConfig
from pprint import pprint

# %% [markdown]
# # Test Experiments

# %% [markdown]
# ## Experiment 1

# %%
# %cd src/experiments/viktor/
# Out:
# /content/abs-project/benchmarl/abs_project/experiments

# %%
exp_config = ExperimentConfig.get_from_yaml()
task = VmasTask.GIVE_WAY.get_from_yaml()
alg = MappoConfig.get_from_yaml()
model = MlpConfig.get_from_yaml()
critic_model = MlpConfig.get_from_yaml()

# %%
task.config["max_steps"] = 200
exp_config.train_device = "cpu"
exp_config.max_n_frames = 12_000

# %%
task.config["final_reward"] = 0.01
task.config["pos_shaping_factor"] = 1.0
task.config["shared_rew"] = True

# %%
task.config
# Out:
# {'max_steps': 100,
#  'mirror_passage': False,
#  'observe_rel_pos': False,
#  'done_on_completion': False,
#  'final_reward': 0.01,
#  'pos_shaping_factor': 1.0,
#  'shared_rew': True}

# %%
experiment = Experiment(
    task=task,
    algorithm_config=alg,
    model_config=model,
    critic_model_config=critic_model,
    seed=0,
    config=exp_config
)
# Out:
# /Users/itonkdong/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/utils.py:326: UserWarning: Scenario kwargs: {'shared_rew': True} passed but not used by the scenario. This will turn into an error in future versions.
#   warnings.warn(
# /Users/itonkdong/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/objectives/ppo.py:445: DeprecationWarning: 'critic_coef' is deprecated and will be removed in torchrl v0.11. Please use 'critic_coeff' instead.
#   warnings.warn(
# /Users/itonkdong/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/objectives/ppo.py:511: DeprecationWarning: 'entropy_coef' is deprecated and will be removed in torchrl v0.11. Please use 'entropy_coeff' instead.
#   warnings.warn(
# Finishing previous runs because reinit is set to 'default'.
# wandb: ERROR Control-C detected -- Run data was not synced
# ---------------------------------------------------------------------------
# ...

# %%
experiment.run()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/protobuf/internal/well_known_types.py:178: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   self.FromDatetime(datetime.datetime.utcnow())
#   0%|          | 0/2 [00:00<?, ?it/s]wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# /usr/local/lib/python3.12/dist-packages/torchvision/io/_video_deprecation_warning.py:9: UserWarning: The video decoding and encoding capabilities of torchvision are deprecated from version 0.22 and will be removed in version 0.24. We recommend that you migrate to TorchCodec, where we'll consolidate the future decoding/encoding capabilities of PyTorch: https://github.com/pytorch/torchcodec
#   warnings.warn(
# ...
# mean return = 0.9418590664863586: 100%|██████████| 2/2 [00:43<00:00, 20.83s/it]
# ...

# %% [markdown]
# # Experiment 2

# %%
exp_config = ExperimentConfig.get_from_yaml()
task = VmasTask.JOINT_PASSAGE_SIZE.get_from_yaml()
alg = MaddpgConfig.get_from_yaml()
model = MlpConfig.get_from_yaml()
critic_model = MlpConfig.get_from_yaml()

# %%
task.config["max_steps"] = 200
ITERATIONS = 150

# %%
FRAMES_PER_BATCH = exp_config.on_policy_collected_frames_per_batch
DO_EVERY = 15

# %%
# experiment
exp_config.train_device = "mps"

exp_config.checkpoint_interval = FRAMES_PER_BATCH * DO_EVERY
exp_config.on_policy_n_envs_per_worker = 16
exp_config.checkpoint_at_end = True

# ==================================================
exp_config.max_n_iters = ITERATIONS
exp_config.max_n_frames = None

# %%
exp_config.evaluation_interval = FRAMES_PER_BATCH * DO_EVERY
experiment = Experiment(
    task=task,
    algorithm_config=alg,
    model_config=model,
    critic_model_config=critic_model,
    seed=0,
    config=exp_config
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # pydev_debug_cell
#       2 exp_config.evaluation_interval = FRAMES_PER_BATCH * DO_EVERY
# ----> 3 experiment = Experiment(
#       4     task=task,
#       5     algorithm_config=alg,
#       6     model_config=model,
#       7     critic_model_config=critic_model,
#       8     seed=0,
#       9     config=exp_config
#      10 )
#
# File ~/Work/Fax/ABS/BenchMARL/benchmarl/experiment/experiment.py:371, in Experiment.__init__(self, task, algorithm_config, model_config, seed, config, critic_model_config, callbacks)
#     368 self.algorithm_config = algorithm_config
#     369 self.seed = seed
# --> 371 self._setup()
#     373 self.total_time = 0
#     374 self.total_frames = 0
#
# File ~/Work/Fax/ABS/BenchMARL/benchmarl/experiment/experiment.py:392, in Experiment._setup(self)
# ...

# %%
experiment.run()
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# /Users/itonkdong/miniconda3/envs/abs/lib/python3.11/site-packages/torchvision/io/_video_deprecation_warning.py:9: UserWarning: The video decoding and encoding capabilities of torchvision are deprecated from version 0.22 and will be removed in version 0.24. We recommend that you migrate to TorchCodec, where we'll consolidate the future decoding/encoding capabilities of PyTorch: https://github.com/pytorch/torchcodec
#   warnings.warn(
# ...

# %%
# !git config --global user.email "kostadinoskiviktor@yahoo.com"
# !git config --global user.username "itonkdong"

# %%
# !git add .

# %%
# !git commit -m "experiments on $(date)"
# Out:
# [main 5ad7086] experiments on Mon Jan 12 04:24:47 PM UTC 2026
#  92 files changed, 2209 insertions(+)
#  create mode 100644 benchmarl/abs_project/experiments/mappo_reverse_transport_mlp__08eb709a_26_01_12-16_18_13/config.pkl
#  create mode 100644 benchmarl/abs_project/experiments/mappo_reverse_transport_mlp__08eb709a_26_01_12-16_18_13/mappo_reverse_transport_mlp__08eb709a_26_01_12-16_18_13.json
#  create mode 100644 benchmarl/abs_project/experiments/mappo_reverse_transport_mlp__08eb709a_26_01_12-16_18_13/mappo_reverse_transport_mlp__08eb709a_26_01_12-16_18_13/scalars/collection_agents_reward_episode_reward_max.csv
#  create mode 100644 benchmarl/abs_project/experiments/mappo_reverse_transport_mlp__08eb709a_26_01_12-16_18_13/mappo_reverse_transport_mlp__08eb709a_26_01_12-16_18_13/scalars/collection_agents_reward_episode_reward_mean.csv
# ...

# %%
# !git remote set-url origin https://itonkdong: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@github.com/itonkdong/abs-project.git

# %%
# !git push origin main
# Out:
# Enumerating objects: 110, done.
# Counting objects: 100% (110/110), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (61/61), done.
# Writing objects: 100% (106/106), 361.04 KiB | 15.70 MiB/s, done.
# Total 106 (delta 12), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (12/12), completed with 3 local objects.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/Itonkdong/abs-project.git
# To https://github.com/itonkdong/abs-project.git
#    27c7ed3..5ad7086  main -> main
