# %% [markdown]
# # ABS Project Andrea Notebook

# %%
# !git clone https://github.com/Itonkdong/abs-project.git
# Out:
# Cloning into 'abs-project'...
# remote: Enumerating objects: 650, done.
# remote: Counting objects: 100% (650/650), done.
# remote: Compressing objects: 100% (446/446), done.
# remote: Total 650 (delta 147), reused 625 (delta 126), pack-reused 0 (from 0)
# Receiving objects: 100% (650/650), 3.90 MiB | 9.93 MiB/s, done.
# Resolving deltas: 100% (147/147), done.

# %%
# %cd abs-project/
# Out:
# /content/abs-project

# %%
# !pip install -U torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 75.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 47.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 9.2 MB/s eta 0:00:00
# ...

# %%
# !pip install -r docs/requirements.txt
# Out:
# ...
#   Cloning https://github.com/matteobettini/benchmarl_sphinx_theme.git to /tmp/pip-req-build-0aflyqbs
#   Running command git clone --filter=blob:none --quiet https://github.com/matteobettini/benchmarl_sphinx_theme.git /tmp/pip-req-build-0aflyqbs
#   Resolved https://github.com/matteobettini/benchmarl_sphinx_theme.git to commit 28949dd4821445c7190b2f7e6645a3c6827dc321
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 51.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 77.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 144.0 MB/s eta 0:00:00
# ...

# %%
# %cd abs-project/
# Out:
# /content/abs-project

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/abs-project
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 51.8 MB/s eta 0:00:00
# ...
#   Building editable for benchmarl (pyproject.toml) ... done
#   Created wheel for benchmarl: filename=benchmarl-1.5.1-0.editable-py3-none-any.whl size=2989 sha256=1516a90a67956b5f69a98f611cb17c569b371f786f430e34b06c1db516a1f2e9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3co732nt/wheels/17/bb/73/095a7528c44a684f321949014f91c338b77d999ab142e56c3d
# Successfully built benchmarl
# ...

# %%
# !apt-get update
# !apt-get install -y x11-utils python3-opengl xvfb
# !pip install pyvirtualdisplay
import pyvirtualdisplay
display = pyvirtualdisplay.Display(visible=False, size=(1400, 900))
display.start()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,233 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,865 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
from benchmarl.algorithms import MappoConfig, QmixConfig, MasacConfig
from benchmarl.benchmark import Benchmark
from benchmarl.environments import VmasTask
from benchmarl.experiment import Experiment, ExperimentConfig
from benchmarl.models import MlpConfig
from pprint import pprint

# %% [markdown]
# # Test Experiments

# %% [markdown]
# ## Experiment 1

# %%
# %cd src/experiments/andrea/
# Out:
# /content/abs-project/src/experiments/andrea

# %%
exp_config = ExperimentConfig.get_from_yaml()
task = VmasTask.REVERSE_TRANSPORT.get_from_yaml()
alg = MappoConfig.get_from_yaml()
model = MlpConfig.get_from_yaml()
critic_model = MlpConfig.get_from_yaml()

# %%
task.config["max_steps"] = 200
exp_config.train_device = "cuda"
exp_config.max_n_frames = 12_000

# %%
task.config
# Out:
# {'max_steps': 200,
#  'n_agents': 4,
#  'package_width': 0.6,
#  'package_length': 0.6,
#  'package_mass': 50}

# %%
experiment = Experiment(
    task=task,
    algorithm_config=alg,
    model_config=model,
    critic_model_config=critic_model,
    seed=0,
    config=exp_config
)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchrl/objectives/ppo.py:445: DeprecationWarning: 'critic_coef' is deprecated and will be removed in torchrl v0.11. Please use 'critic_coeff' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchrl/objectives/ppo.py:511: DeprecationWarning: 'entropy_coef' is deprecated and will be removed in torchrl v0.11. Please use 'entropy_coeff' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# ...

# %%
experiment.run()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/google/protobuf/internal/well_known_types.py:178: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   self.FromDatetime(datetime.datetime.utcnow())
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# /usr/local/lib/python3.12/dist-packages/google/protobuf/internal/well_known_types.py:178: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   self.FromDatetime(datetime.datetime.utcnow())
# ...

# %%
# !git config --global user.email "andrea.stevanoska2@gmail.com"
# !git config --global user.username "Andrea-444"

# %%
# !git add .

# %%
# !git commit -m "experiments on $(date)"
# Out:
# [main 2eeded8] experiments on Mon Jan 12 06:41:21 PM UTC 2026
#  46 files changed, 1100 insertions(+)
#  create mode 100644 src/experiments/andrea/mappo_reverse_transport_mlp__e9a28317_26_01_12-18_38_05/config.pkl
#  create mode 100644 src/experiments/andrea/mappo_reverse_transport_mlp__e9a28317_26_01_12-18_38_05/mappo_reverse_transport_mlp__e9a28317_26_01_12-18_38_05.json
#  create mode 100644 src/experiments/andrea/mappo_reverse_transport_mlp__e9a28317_26_01_12-18_38_05/mappo_reverse_transport_mlp__e9a28317_26_01_12-18_38_05/scalars/collection_agents_reward_episode_reward_max.csv
#  create mode 100644 src/experiments/andrea/mappo_reverse_transport_mlp__e9a28317_26_01_12-18_38_05/mappo_reverse_transport_mlp__e9a28317_26_01_12-18_38_05/scalars/collection_agents_reward_episode_reward_mean.csv
# ...

# %%
# !git remote set-url origin https://Andrea-444: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@github.com/itonkdong/abs-project.git

# %%
# !git push origin main
# Out:
# Enumerating objects: 60, done.
# Counting objects: 100% (60/60), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (24/24), done.
# Writing objects: 100% (56/56), 246.86 KiB | 12.34 MiB/s, done.
# Total 56 (delta 2), reused 7 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 1 local object.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/Itonkdong/abs-project.git
# To https://github.com/itonkdong/abs-project.git
#    b305ca0..2eeded8  main -> main
