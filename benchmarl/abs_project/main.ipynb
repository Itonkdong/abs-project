# %% [markdown]
# # ABS Project Main Notebook

# %%
from benchmarl.algorithms import MappoConfig, QmixConfig, MasacConfig
from benchmarl.benchmark import Benchmark
from benchmarl.environments import VmasTask
from benchmarl.experiment import Experiment, ExperimentConfig
from benchmarl.models import MlpConfig
from pprint import pprint

# %% [markdown]
# # Test Experiments

# %% [markdown]
# ## Experiment 1

# %%
exp_config = ExperimentConfig.get_from_yaml()
task = VmasTask.BALANCE.get_from_yaml()
alg = MappoConfig.get_from_yaml()
model = MlpConfig.get_from_yaml()
critic_model = MlpConfig.get_from_yaml()

# %%
pprint(exp_config)
# Out:
# ExperimentConfig(sampling_device='cpu',
#                  train_device='cpu',
#                  buffer_device='cpu',
#                  share_policy_params=True,
#                  prefer_continuous_actions=True,
#                  collect_with_grad=False,
#                  parallel_collection=False,
#                  gamma=0.99,
#                  lr=5e-05,
#                  adam_eps=1e-06,
#                  adam_extra_kwargs={},
#                  clip_grad_norm=True,
#                  clip_grad_val=5,
#                  soft_target_update=True,
#                  polyak_tau=0.005,
#                  hard_target_update_frequency=5,
#                  exploration_eps_init=0.8,
#                  exploration_eps_end=0.01,
#                  exploration_anneal_frames=None,
#                  max_n_iters=None,
#                  max_n_frames=3000000,
#                  on_policy_collected_frames_per_batch=6000,
#                  on_policy_n_envs_per_worker=10,
#                  on_policy_n_minibatch_iters=45,
#                  on_policy_minibatch_size=400,
#                  off_policy_collected_frames_per_batch=6000,
#                  off_policy_n_envs_per_worker=10,
#                  off_policy_n_optimizer_steps=1000,
#                  off_policy_train_batch_size=128,
#                  off_policy_memory_size=1000000,
#                  off_policy_init_random_frames=0,
#                  off_policy_use_prioritized_replay_buffer=False,
#                  off_policy_prb_alpha=0.6,
#                  off_policy_prb_beta=0.4,
#                  evaluation=True,
#                  render=True,
#                  evaluation_interval=120000,
#                  evaluation_episodes=10,
#                  evaluation_deterministic_actions=True,
#                  evaluation_static=False,
#                  loggers=['csv', 'wandb'],
#                  project_name='benchmarl',
#                  wandb_extra_kwargs={},
#                  create_json=True,
#                  save_folder=None,
#                  restore_file=None,
#                  restore_map_location=None,
#                  checkpoint_interval=0,
#                  checkpoint_at_end=False,
#                  keep_checkpoints_num=3,
#                  exclude_buffer_from_checkpoint=False)

# %%
pprint(critic_model)
# Out:
# MlpConfig(num_cells=[256, 256],
#           layer_class=<class 'torch.nn.modules.linear.Linear'>,
#           activation_class=<class 'torch.nn.modules.activation.Tanh'>,
#           activation_kwargs=None,
#           norm_class=None,
#           norm_kwargs=None,
#           num_feature_dims=1)

# %%
experiment = Experiment(
    task=task,
    algorithm_config=alg,
    model_config=model,
    critic_model_config=critic_model,
    seed=0,
    config=exp_config
)
# Out:
# /Users/itonkdong/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/objectives/ppo.py:445: DeprecationWarning: 'critic_coef' is deprecated and will be removed in torchrl v0.11. Please use 'critic_coeff' instead.
#   warnings.warn(
# /Users/itonkdong/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/objectives/ppo.py:511: DeprecationWarning: 'entropy_coef' is deprecated and will be removed in torchrl v0.11. Please use 'entropy_coeff' instead.
#   warnings.warn(
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/Users/itonkdong/Work/Fax/ABS/BenchMARL/benchmarl/abs_project/mappo_balance_mlp__054a17f5_26_01_07-17_34_54/wandb/run-20260107_173455-mappo_balance_mlp__054a17f5_26_01_07-17_34_54</code>
# Syncing run <strong><a href='https://wandb.ai/itonkdong-org/benchmarl/runs/mappo_balance_mlp__054a17f5_26_01_07-17_34_54' target="_blank">mappo_balance_mlp__054a17f5_26_01_07-17_34_54</a></strong> to <a href='https://wandb.ai/itonkdong-org/benchmarl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/itonkdong-org/benchmarl' target="_blank">https://wandb.ai/itonkdong-org/benchmarl</a>
#  View run at <a href='https://wandb.ai/itonkdong-org/benchmarl/runs/mappo_balance_mlp__054a17f5_26_01_07-17_34_54' target="_blank">https://wandb.ai/itonkdong-org/benchmarl/runs/mappo_balance_mlp__054a17f5_26_01_07-17_34_54</a>

# %%
experiment.run()
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# /Users/itonkdong/miniconda3/envs/abs/lib/python3.11/site-packages/torchvision/io/_video_deprecation_warning.py:9: UserWarning: The video decoding and encoding capabilities of torchvision are deprecated from version 0.22 and will be removed in version 0.24. We recommend that you migrate to TorchCodec, where we'll consolidate the future decoding/encoding capabilities of PyTorch: https://github.com/pytorch/torchcodec
#   warnings.warn(
# mean return = 2.098975658416748:   2%|▏         | 9/500 [01:00<47:48,  5.84s/it]
# Experiment was closed gracefully
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>collection/agents/info/ground_rew</td><td>▃▁▂▃▄▆██▇</td></tr><tr><td>collection/agents/info/pos_rew</td><td>▁▁▁▂▂▃▄▅█</td></tr><tr><td>collection/agents/reward/episode_reward_max</td><td>▁▁▁▂▃▂▅▅█</td></tr><tr><td>collection/agents/reward/episode_reward_mean</td><td>▁▁▂▂▃▅▆▇█</td></tr><tr><td>collection/agents/reward/episode_reward_min</td><td>▁▂▂▁▂▅▅▆█</td></tr><tr><td>collection/reward/episode_reward_max</td><td>▁▁▁▂▃▂▅▅█</td></tr><tr><td>collection/reward/episode_reward_mean</td><td>▁▁▂▂▃▅▆▇█</td></tr><tr><td>collection/reward/episode_reward_min</td><td>▁▂▂▁▂▅▅▆█</td></tr><tr><td>collection/reward/reward_max</td><td>▁▃▂▃▄▅▆▅█</td></tr><tr><td>collection/reward/reward_mean</td><td>▂▁▂▂▃▅▆▇█</td></tr><tr><td>+26</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>collection/agents/info/ground_rew</td><td>-0.00667</td></tr><tr><td>collection/agents/info/pos_rew</td><td>0.03119</td></tr><tr><td>collection/agents/reward/episode_reward_max</td><td>8.05424</td></tr><tr><td>collection/agents/reward/episode_reward_mean</td><td>2.09898</td></tr><tr><td>collection/agents/reward/episode_reward_min</td><td>-9.49818</td></tr><tr><td>collection/reward/episode_reward_max</td><td>8.05424</td></tr><tr><td>collection/reward/episode_reward_mean</td><td>2.09898</td></tr><tr><td>collection/reward/episode_reward_min</td><td>-9.49818</td></tr><tr><td>collection/reward/reward_max</td><td>0.49101</td></tr><tr><td>collection/reward/reward_mean</td><td>0.02452</td></tr><tr><td>+26</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">mappo_balance_mlp__054a17f5_26_01_07-17_34_54</strong> at: <a href='https://wandb.ai/itonkdong-org/benchmarl/runs/mappo_balance_mlp__054a17f5_26_01_07-17_34_54' target="_blank">https://wandb.ai/itonkdong-org/benchmarl/runs/mappo_balance_mlp__054a17f5_26_01_07-17_34_54</a><br> View project at: <a href='https://wandb.ai/itonkdong-org/benchmarl' target="_blank">https://wandb.ai/itonkdong-org/benchmarl</a><br>Synced 4 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./mappo_balance_mlp__054a17f5_26_01_07-17_34_54/wandb/run-20260107_173455-mappo_balance_mlp__054a17f5_26_01_07-17_34_54/logs</code>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 experiment.run()
#
# File ~/Work/Fax/ABS/BenchMARL/benchmarl/experiment/experiment.py:661, in Experiment.run(self)
#     659     print("\n\nExperiment was closed gracefully\n\n")
#     660     self.close()
# --> 661     raise interrupt
#     662 except Exception as err:
#     663     print("\n\nExperiment failed and is closing gracefully\n\n")
#
# File ~/Work/Fax/ABS/BenchMARL/benchmarl/experiment/experiment.py:657, in Experiment.run(self)
#     655     seed_everything(self.seed)
#     656     torch.cuda.empty_cache()
# --> 657     self._collection_loop()
#     658 except KeyboardInterrupt as interrupt:
#     659     print("\n\nExperiment was closed gracefully\n\n")
#
# File ~/Work/Fax/ABS/BenchMARL/benchmarl/experiment/experiment.py:694, in Experiment._collection_loop(self)
#     692 iteration_start = time.time()
#     693 if not self.config.collect_with_grad:
# --> 694     batch = next(iterator)
#     695 else:
#     696     with set_exploration_type(ExplorationType.RANDOM):
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/collectors/collectors.py:343, in DataCollectorBase.__iter__(self)
#     341 def __iter__(self) -> Iterator[TensorDictBase]:
#     342     try:
# --> 343         yield from self.iterator()
#     344     except Exception:
#     345         self.shutdown()
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/collectors/collectors.py:1268, in SyncDataCollector.iterator(self)
#    1266 if self.verbose:
#    1267     torchrl_logger.info("Collector: rollout.")
# -> 1268 tensordict_out = self.rollout()
#    1269 if tensordict_out is None:
#    1270     # if a replay buffer is passed and self.extend_buffer=False, there is no tensordict_out
#    1271     #  frames are updated within the rollout function
#    1272     if self.verbose:
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/_utils.py:404, in accept_remote_rref_invocation.<locals>.unpack_rref_and_invoke_function(self, *args, **kwargs)
#     402 if not _os_is_windows and isinstance(self, torch._C._distributed_rpc.PyRRef):
#     403     self = self.local_value()
# --> 404 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/collectors/collectors.py:1534, in SyncDataCollector.rollout(self)
#    1532 else:
#    1533     env_input = self._shuttle
# -> 1534 env_output, env_next_output = self.env.step_and_maybe_reset(env_input)
#    1536 if self._shuttle is not env_output:
#    1537     # ad-hoc update shuttle
#    1538     next_data = env_output.get("next")
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/envs/common.py:3670, in EnvBase.step_and_maybe_reset(self, tensordict)
#    3668 if tensordict.device != self.device:
#    3669     tensordict = tensordict.to(self.device)
# -> 3670 tensordict = self.step(tensordict)
#    3671 # done and truncated are in done_keys
#    3672 # We read if any key is done.
#    3673 tensordict_ = self._step_mdp(tensordict)
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/envs/common.py:2102, in EnvBase.step(self, tensordict)
#    2099 next_preset = tensordict.get("next", None)
#    2101 if next_tensordict is None:
# -> 2102     next_tensordict = self._step(tensordict)
#    2103     next_tensordict = self._step_proc_data(next_tensordict)
#    2104 if next_preset is not None:
#    2105     # tensordict could already have a "next" key
#    2106     # this could be done more efficiently by not excluding but just passing
#    2107     # the necessary keys
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/envs/transforms/transforms.py:1230, in TransformedEnv._step(self, tensordict)
#    1227         tensordict_batch_size = self.batch_size
#    1229 if next_tensordict is None:
# -> 1230     next_tensordict = self.base_env._step(tensordict_in)
#    1231     if next_preset is not None:
#    1232         # tensordict could already have a "next" key
#    1233         # this could be done more efficiently by not excluding but just passing
#    1234         # the necessary keys
#    1235         next_tensordict.update(
#    1236             next_preset.exclude(*next_tensordict.keys(True, True))
#    1237         )
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/torchrl/envs/libs/vmas.py:570, in VmasWrapper._step(self, tensordict)
#     567     action_list += group_action_list
#     568 action = [action_list[agent_indices[i]] for i in range(self.n_agents)]
# --> 570 obs, rews, dones, infos = self._env.step(action)
#     572 dones = self.read_done(dones)
#     574 source = {"done": dones, "terminated": dones.clone()}
#
# File ~/miniconda3/envs/abs/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/environment/environment.py:400, in Environment.step(self, actions)
#     396 self.scenario.post_step()
#     398 self.steps += 1
# --> 400 return self._get_from_scenario(
#     401     get_observations=True,
#     402     get_infos=True,
#     403     get_rewards=True,
#     404     get_dones=True,
#     405 )
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/environment/environment.py:278, in Environment._get_from_scenario(self, get_observations, get_rewards, get_infos, get_dones, dict_agent_names)
#     276 if get_rewards:
#     277     for agent in self.agents:
# --> 278         reward = self.scenario.reward(agent).clone()
#     279         if dict_agent_names:
#     280             rewards.update({agent.name: reward})
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/scenarios/balance.py:230, in Scenario.reward(self, agent)
#     227 self.pos_rew[:] = 0
#     228 self.ground_rew[:] = 0
# --> 230 self.compute_on_the_ground()
#     231 self.package_dist = torch.linalg.vector_norm(
#     232     self.package.state.pos - self.package.goal.state.pos, dim=1
#     233 )
#     235 self.ground_rew[self.on_the_ground] = self.fall_reward
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/scenarios/balance.py:219, in Scenario.compute_on_the_ground(self)
#     218 def compute_on_the_ground(self):
# --> 219     self.on_the_ground = self.world.is_overlapping(
#     220         self.line, self.floor
#     221     ) + self.world.is_overlapping(self.package, self.floor)
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/core.py:1932, in World.is_overlapping(self, entity_a, entity_b, env_index)
#    1912 # Sphere sphere, sphere line, line line, line box, box box
#    1913 if (
#    1914     (isinstance(a_shape, Sphere) and isinstance(b_shape, Sphere))
#    1915     or (
#    (...)   1930     or (isinstance(entity_a.shape, Box) and isinstance(entity_b.shape, Box))
#    1931 ):
# -> 1932     return self.get_distance(entity_a, entity_b, env_index) < 0
#    1933 elif (
#    1934     isinstance(entity_a.shape, Box)
#    1935     and isinstance(entity_b.shape, Sphere)
#    1936     or isinstance(entity_b.shape, Box)
#    1937     and isinstance(entity_a.shape, Sphere)
#    1938 ):
#    1939     box, sphere = (
#    1940         (entity_a, entity_b)
#    1941         if isinstance(entity_b.shape, Sphere)
#    1942         else (entity_b, entity_a)
#    1943     )
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/core.py:1879, in World.get_distance(self, entity_a, entity_b, env_index)
#    1868 elif (
#    1869     isinstance(entity_a.shape, Box)
#    1870     and isinstance(entity_b.shape, Line)
#    1871     or isinstance(entity_b.shape, Box)
#    1872     and isinstance(entity_a.shape, Line)
#    1873 ):
#    1874     box, line = (
#    1875         (entity_a, entity_b)
#    1876         if isinstance(entity_b.shape, Line)
#    1877         else (entity_b, entity_a)
#    1878     )
# -> 1879     point_box, point_line = _get_closest_line_box(
#    1880         box.state.pos,
#    1881         box.state.rot,
#    1882         box.shape.width,
#    1883         box.shape.length,
#    1884         line.state.pos,
#    1885         line.state.rot,
#    1886         line.shape.length,
#    1887     )
#    1888     dist = torch.linalg.vector_norm(point_box - point_line, dim=1)
#    1889     return_value = dist - LINE_MIN_DIST
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/physics.py:366, in _get_closest_line_box(box_pos, box_rot, box_width, box_length, line_pos, line_rot, line_length)
#     354 closest_point_2 = torch.full(
#     355     box_pos.shape,
#     356     float("inf"),
#     357     device=box_pos.device,
#     358     dtype=torch.float32,
#     359 )
#     360 distance = torch.full(
#     361     box_pos.shape[:-1],
#     362     float("inf"),
#     363     device=box_pos.device,
#     364     dtype=torch.float32,
#     365 )
# --> 366 ps_box, ps_line = _get_closest_points_line_line(
#     367     lines_pos,
#     368     lines_rot,
#     369     lines_length,
#     370     line_pos.unsqueeze(0).expand(lines_pos.shape),
#     371     line_rot.unsqueeze(0).expand(lines_rot.shape),
#     372     line_length.unsqueeze(0).expand(lines_length.shape),
#     373 )
#     375 for p_box, p_line in zip(ps_box.unbind(0), ps_line.unbind(0)):
#     376     d = torch.linalg.vector_norm(p_box - p_line, dim=-1)
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/physics.py:164, in _get_closest_points_line_line(line_pos, line_rot, line_length, line2_pos, line2_rot, line2_length)
#     161 point_a1, point_b1 = points_a.unbind(0)
#     162 point_a2, point_b2 = points_b.unbind(0)
# --> 164 point_i, d_i = _get_intersection_point_line_line(
#     165     point_a1, point_a2, point_b1, point_b2
#     166 )
#     168 (
#     169     point_a1_line_b,
#     170     point_a2_line_b,
#    (...)    179     0
#     180 )
#     182 point_pairs = (
#     183     (point_a1, point_a1_line_b),
#     184     (point_a2, point_a2_line_b),
#     185     (point_b1_line_a, point_b1),
#     186     (point_b2_line_a, point_b2),
#     187 )
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/physics.py:232, in _get_intersection_point_line_line(point_a1, point_a2, point_b1, point_b2)
#     230 q = point_b1
#     231 cross_q_minus_p_r = TorchUtils.cross(q - p, r)
# --> 232 cross_q_minus_p_s = TorchUtils.cross(q - p, s)
#     233 cross_r_s = TorchUtils.cross(r, s)
#     234 u = cross_q_minus_p_r / cross_r_s
#
# File ~/miniconda3/envs/abs/lib/python3.11/site-packages/vmas/simulator/utils.py:197, in TorchUtils.cross(vector_a, vector_b)
#     193 @staticmethod
#     194 def cross(vector_a: Tensor, vector_b: Tensor):
#     195     return (
#     196         vector_a[..., X] * vector_b[..., Y] - vector_a[..., Y] * vector_b[..., X]
# --> 197     ).unsqueeze(-1)
#
# KeyboardInterrupt:
